# %%
import string
import random

import pandas as pd
import numpy as np

# %%
# gernerate dataframe
df = pd.DataFrame([{
    'name': ''.join(random.sample(list(string.ascii_lowercase), 5)),
    'email': ''.join(random.sample(list(string.ascii_lowercase), 10)) + '@gmail.com',
    'age': random.randint(18, 30),
    'value': random.random() * 100
} for _ in range(50)])

df
# Out:
#     age                 email   name      value
# 0    21  hlcdiebofx@gmail.com  arkum  69.011718
# 1    26  tndahuifem@gmail.com  jefgz  49.576658
# 2    26  ctepgnzahu@gmail.com  rftpo  51.803979
# 3    21  uaezslbdko@gmail.com  zlmch  67.198751
# 4    18  ugbzijqoep@gmail.com  vewir  75.411472
# 5    24  efzgbnvspa@gmail.com  onmxe  63.961503
# 6    19  gbeschudpm@gmail.com  mbnui   5.090296
# 7    30  pkojshyuna@gmail.com  gzdfx  99.842268
# 8    24  efwdozpgan@gmail.com  kljsu   9.197525
# 9    23  thbczlpfer@gmail.com  cgnpy  13.822499
# 10   30  muszqovfec@gmail.com  mblgk  68.021126
# 11   18  yuerhctxwq@gmail.com  vrmkc  51.846152
# 12   27  yijukocmxs@gmail.com  hucoi  43.156452
# 13   18  mhjbplieqt@gmail.com  xtvjb  45.923281
# 14   27  natglsqxec@gmail.com  sfoed  71.259322
# 15   30  mlfkpzquot@gmail.com  vrpab  56.353550
# 16   23  ynulvstrxg@gmail.com  dhleu   0.357889
# 17   25  uafkhegjqi@gmail.com  ulang  67.699411
# 18   28  pzowdtergq@gmail.com  vkgtl  15.966962
# ...

# %%
df['E'].astype('category')
# Out:
# 0    100
# 1    101
# 2    100
# 3    101
# 4    101
# 5    101
# 6    107
# 7    107
# 8    104
# 9    100
# Name: E, dtype: category
# Categories (4, int64): [100 < 101 < 104 < 107]
